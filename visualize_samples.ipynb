# %% [markdown]
# # CARRADA Dataset: Camera and Automotive Radar with Range-Angle-Doppler Annotations
#
# This notebook shows samples of annotated radar data and how to use utils functions

# %%
# %matplotlib inline
import os
import json
import numpy as np
from IPython.display import Image

from carrada_dataset.utils import CARRADA_HOME
from carrada_dataset.utils.configurable import Configurable
from carrada_dataset.utils.visualize_signal import SignalVisualizer
from carrada_dataset.utils.transform_annotations import AnnotationTransformer
from carrada_dataset.utils.generate_annotations import AnnotationGenerator
from carrada_dataset.utils.transform_data import DataTransformer

# %%
# Set path
# %run ./scripts/set_path.py '/home/yahia/Downloads/'

# %%
# Sample to visualize
# seq_name = '2019-09-16-13-20-20'
# instances = ['000670', '000673']
# frame_name = '000100'
seq_name = '2019-09-16-13-18-33'
instances = ['000015', '000228']
frame_name = '000100'

# %%
# Define paths
config_path = os.path.join(CARRADA_HOME, 'config.ini')
config = Configurable(config_path).config
warehouse = config['data']['warehouse']
carrada = os.path.join(warehouse, 'Carrada')
seq_path = os.path.join(carrada, seq_name)
rd_path = os.path.join(seq_path, 'range_doppler_numpy', frame_name + '.npy')
ra_path = os.path.join(seq_path, 'range_angle_numpy', frame_name + '.npy')
ad_path = os.path.join(seq_path, 'angle_doppler_processed', frame_name + '.npy')
img_path = os.path.join(seq_path, 'camera_images', frame_name + '.jpg')

'''
# Path to the RAD tensor (soon available)
rad_path = os.path.join(seq_path, 'RAD_numpy', frame_name + '.npy')
'''

annotations_path = os.path.join(carrada, 'annotations_frame_oriented.json')
# Load data

# Annotations
with open(annotations_path, 'r') as fp:
    annotations = json.load(fp)
annotations = annotations[seq_name][frame_name]  # Keep annotations of interest

# Range-angle and range-Doppler matrices
'''
# the RA and RD matrices can be computed directly from the RAD tensor
rad_matrix = np.load(rad_path)
data_transformer = DataTransformer(rad_matrix)
ra_matrix = data_transformer.to_ra()
rd_matrix = data_transformer.to_rd()
'''
ra_matrix = np.load(ra_path)
rd_matrix = np.load(rd_path)
ad_matrix = np.load(ad_path)
# Camera image of the scene
print('Camera image of the scene {}, frame {}'.format(seq_name, frame_name))
img = Image(img_path)
display(img)
# Out:
# Camera image of the scene 2019-09-16-13-18-33, frame 000100

# %%
signal_visualizer = SignalVisualizer(rd_matrix)
print('Raw Range-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='range_doppler', color_scale=False,
                             rotation=True, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_doppler'][annotation_type]
        annot_generator = AnnotationGenerator(rd_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Doppler with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/rd_{}.png'.format(annotation_type),
                                                signal_type='range_doppler', color_scale=False,
                                                rotation=True, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# Raw Range-Doppler representation:
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 7
#       5 for annotation_type in ['sparse', 'dense', 'box']:
#       6     for i, instance in enumerate(instances):
# ----> 7         points = annotations[instance]['range_doppler'][annotation_type]
#       8         annot_generator = AnnotationGenerator(rd_matrix.shape, points)
#       9         if annotation_type is 'sparse':
#
# KeyError: '000015'

# %%
# Range-Angle visualization
# Range-Angle visualization
# Range-Doppler visualization

signal_visualizer = SignalVisualizer(ra_matrix)
print('Raw Range-Angle representation:')
signal_visualizer.save_scale(path='.', signal_type='range_angle', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_angle'][annotation_type]
        annot_generator = AnnotationGenerator(ra_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Angle with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                                signal_type='range_angle', color_scale=False,
                                                rotation=False, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Raw Range-Angle representation:
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 11
#       9 for annotation_type in ['sparse', 'dense', 'box']:
#      10     for i, instance in enumerate(instances):
# ---> 11         points = annotations[instance]['range_angle'][annotation_type]
#      12         annot_generator = AnnotationGenerator(ra_matrix.shape, points)
#      13         if annotation_type is 'sparse':
#
# KeyError: '000015'

# %%
signal_visualizer = SignalVisualizer(ad_matrix)
print('Raw Angle-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
print('Range-Angle with {} annotations:'.format(annotation_type))
signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                            signal_type='range_angle', color_scale=False,
                                            rotation=False, save_img=False, plot_img=True)
signal_visualizer.reset_annotation()
# Out:
# Raw Angle-Doppler representation:
# Range-Angle with sparse annotations:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[39], line 6
#       3 signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
#       4                              rotation=False, save_img=False, plot_img=True)
#       5 print('Range-Angle with {} annotations:'.format(annotation_type))
# ----> 6 signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
#       7                                             signal_type='range_angle', color_scale=False,
#       8                                             rotation=False, save_img=False, plot_img=True)
#       9 signal_visualizer.reset_annotation()
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:161, in SignalVisualizer.save_multiple_annotations(self, path, signal_type, color_scale, rotation, save_img, plot_img)
#     141 def save_multiple_annotations(self, path, signal_type='range_doppler', color_scale=None,
#     142                               rotation=False, save_img=True, plot_img=False):
#     143     """
#     144     Method to save the image with all the added annotations
#     145
#    (...)
#     159         Plot the image
#     160     """
# --> 161     transformed_image = self._get_multiple_annotated_image()
#     162     img = self._format_img(transformed_image, signal_type, color_scale, rotation)
#     163     if save_img:
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:255, in SignalVisualizer._get_multiple_annotated_image(self)
#     253 zeros = np.zeros(mask.shape).astype(np.uint8)
#     254 if len(self.masks) == 0:
# --> 255     raise Exception('You need to add annotation before visualize it!')
#     256 transformed_image = self.image.copy()
#     257 transformed_image = (transformed_image * 255).astype(np.uint8)
#
# Exception: You need to add annotation before visualize it!

# %%
# Sample to visualize
# seq_name = '2019-09-16-13-20-20'
# instances = ['000670', '000673']
# frame_name = '000100'
seq_name = '2020-02-28-12-23-30'
instances = ['000010', '000228']
frame_name = '000121'

# %%
# Define paths
config_path = os.path.join(CARRADA_HOME, 'config.ini')
config = Configurable(config_path).config
warehouse = config['data']['warehouse']
carrada = os.path.join(warehouse, 'Carrada')
seq_path = os.path.join(carrada, seq_name)
rd_path = os.path.join(seq_path, 'range_doppler_numpy', frame_name + '.npy')
ra_path = os.path.join(seq_path, 'range_angle_numpy', frame_name + '.npy')
ad_path = os.path.join(seq_path, 'angle_doppler_processed', frame_name + '.npy')
img_path = os.path.join(seq_path, 'camera_images', frame_name + '.jpg')

'''
# Path to the RAD tensor (soon available)
rad_path = os.path.join(seq_path, 'RAD_numpy', frame_name + '.npy')
'''

annotations_path = os.path.join(carrada, 'annotations_frame_oriented.json')
# Load data

# Annotations
with open(annotations_path, 'r') as fp:
    annotations = json.load(fp)
annotations = annotations[seq_name][frame_name]  # Keep annotations of interest

# Range-angle and range-Doppler matrices
'''
# the RA and RD matrices can be computed directly from the RAD tensor
rad_matrix = np.load(rad_path)
data_transformer = DataTransformer(rad_matrix)
ra_matrix = data_transformer.to_ra()
rd_matrix = data_transformer.to_rd()
'''
ra_matrix = np.load(ra_path)
rd_matrix = np.load(rd_path)
ad_matrix = np.load(ad_path)
# Camera image of the scene
print('Camera image of the scene {}, frame {}'.format(seq_name, frame_name))
img = Image(img_path)
display(img)
# Out:
# Camera image of the scene 2020-02-28-12-23-30, frame 000121

# %%
# Sample to visualize
# seq_name = '2019-09-16-13-20-20'
# instances = ['000670', '000673']
# frame_name = '000100'
seq_name = '2020-02-28-13-08-51'
instances = ['000015', '000228']
frame_name = '000130'

# %%
# Define paths
config_path = os.path.join(CARRADA_HOME, 'config.ini')
config = Configurable(config_path).config
warehouse = config['data']['warehouse']
carrada = os.path.join(warehouse, 'Carrada')
seq_path = os.path.join(carrada, seq_name)
rd_path = os.path.join(seq_path, 'range_doppler_numpy', frame_name + '.npy')
ra_path = os.path.join(seq_path, 'range_angle_numpy', frame_name + '.npy')
ad_path = os.path.join(seq_path, 'angle_doppler_processed', frame_name + '.npy')
img_path = os.path.join(seq_path, 'camera_images', frame_name + '.jpg')

'''
# Path to the RAD tensor (soon available)
rad_path = os.path.join(seq_path, 'RAD_numpy', frame_name + '.npy')
'''

annotations_path = os.path.join(carrada, 'annotations_frame_oriented.json')
# Load data

# Annotations
with open(annotations_path, 'r') as fp:
    annotations = json.load(fp)
annotations = annotations[seq_name][frame_name]  # Keep annotations of interest

# Range-angle and range-Doppler matrices
'''
# the RA and RD matrices can be computed directly from the RAD tensor
rad_matrix = np.load(rad_path)
data_transformer = DataTransformer(rad_matrix)
ra_matrix = data_transformer.to_ra()
rd_matrix = data_transformer.to_rd()
'''
ra_matrix = np.load(ra_path)
rd_matrix = np.load(rd_path)
ad_matrix = np.load(ad_path)
# Camera image of the scene
print('Camera image of the scene {}, frame {}'.format(seq_name, frame_name))
img = Image(img_path)
display(img)
# Out:
# Camera image of the scene 2020-02-28-13-08-51, frame 000130

# %%
signal_visualizer = SignalVisualizer(rd_matrix)
print('Raw Range-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='range_doppler', color_scale=False,
                             rotation=True, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_doppler'][annotation_type]
        annot_generator = AnnotationGenerator(rd_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Doppler with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/rd_{}.png'.format(annotation_type),
                                                signal_type='range_doppler', color_scale=False,
                                                rotation=True, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# Raw Range-Doppler representation:
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/3384754158.py:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/3384754158.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 7
#       5 for annotation_type in ['sparse', 'dense', 'box']:
#       6     for i, instance in enumerate(instances):
# ----> 7         points = annotations[instance]['range_doppler'][annotation_type]
#       8         annot_generator = AnnotationGenerator(rd_matrix.shape, points)
#       9         if annotation_type is 'sparse':
#
# KeyError: '000015'

# %%
# Range-Angle visualization
# Range-Angle visualization
# Range-Doppler visualization

signal_visualizer = SignalVisualizer(ra_matrix)
print('Raw Range-Angle representation:')
signal_visualizer.save_scale(path='.', signal_type='range_angle', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_angle'][annotation_type]
        annot_generator = AnnotationGenerator(ra_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Angle with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                                signal_type='range_angle', color_scale=False,
                                                rotation=False, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Raw Range-Angle representation:
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/928262040.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/928262040.py:15: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 11
#       9 for annotation_type in ['sparse', 'dense', 'box']:
#      10     for i, instance in enumerate(instances):
# ---> 11         points = annotations[instance]['range_angle'][annotation_type]
#      12         annot_generator = AnnotationGenerator(ra_matrix.shape, points)
#      13         if annotation_type is 'sparse':
#
# KeyError: '000015'

# %%
signal_visualizer = SignalVisualizer(ad_matrix)
print('Raw Angle-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
print('Range-Angle with {} annotations:'.format(annotation_type))
signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                            signal_type='range_angle', color_scale=False,
                                            rotation=False, save_img=False, plot_img=True)
signal_visualizer.reset_annotation()
# Out:
# Raw Angle-Doppler representation:
# Range-Angle with sparse annotations:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[43], line 6
#       3 signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
#       4                              rotation=False, save_img=False, plot_img=True)
#       5 print('Range-Angle with {} annotations:'.format(annotation_type))
# ----> 6 signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
#       7                                             signal_type='range_angle', color_scale=False,
#       8                                             rotation=False, save_img=False, plot_img=True)
#       9 signal_visualizer.reset_annotation()
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:161, in SignalVisualizer.save_multiple_annotations(self, path, signal_type, color_scale, rotation, save_img, plot_img)
#     141 def save_multiple_annotations(self, path, signal_type='range_doppler', color_scale=None,
#     142                               rotation=False, save_img=True, plot_img=False):
#     143     """
#     144     Method to save the image with all the added annotations
#     145
#    (...)
#     159         Plot the image
#     160     """
# --> 161     transformed_image = self._get_multiple_annotated_image()
#     162     img = self._format_img(transformed_image, signal_type, color_scale, rotation)
#     163     if save_img:
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:255, in SignalVisualizer._get_multiple_annotated_image(self)
#     253 zeros = np.zeros(mask.shape).astype(np.uint8)
#     254 if len(self.masks) == 0:
# --> 255     raise Exception('You need to add annotation before visualize it!')
#     256 transformed_image = self.image.copy()
#     257 transformed_image = (transformed_image * 255).astype(np.uint8)
#
# Exception: You need to add annotation before visualize it!

# %%
# Sample to visualize
# seq_name = '2019-09-16-13-20-20'
# instances = ['000670', '000673']
# frame_name = '000100'
seq_name = '2020-02-28-13-14-35'
instances = ['000015', '000008']
frame_name = '000154'

# %%
# Define paths
config_path = os.path.join(CARRADA_HOME, 'config.ini')
config = Configurable(config_path).config
warehouse = config['data']['warehouse']
carrada = os.path.join(warehouse, 'Carrada')
seq_path = os.path.join(carrada, seq_name)
rd_path = os.path.join(seq_path, 'range_doppler_numpy', frame_name + '.npy')
ra_path = os.path.join(seq_path, 'range_angle_numpy', frame_name + '.npy')
ad_path = os.path.join(seq_path, 'angle_doppler_processed', frame_name + '.npy')
img_path = os.path.join(seq_path, 'camera_images', frame_name + '.jpg')

'''
# Path to the RAD tensor (soon available)
rad_path = os.path.join(seq_path, 'RAD_numpy', frame_name + '.npy')
'''

annotations_path = os.path.join(carrada, 'annotations_frame_oriented.json')
# Load data

# Annotations
with open(annotations_path, 'r') as fp:
    annotations = json.load(fp)
annotations = annotations[seq_name][frame_name]  # Keep annotations of interest

# Range-angle and range-Doppler matrices
'''
# the RA and RD matrices can be computed directly from the RAD tensor
rad_matrix = np.load(rad_path)
data_transformer = DataTransformer(rad_matrix)
ra_matrix = data_transformer.to_ra()
rd_matrix = data_transformer.to_rd()
'''
ra_matrix = np.load(ra_path)
rd_matrix = np.load(rd_path)
ad_matrix = np.load(ad_path)
# Camera image of the scene
print('Camera image of the scene {}, frame {}'.format(seq_name, frame_name))
img = Image(img_path)
display(img)
# Out:
# Camera image of the scene 2020-02-28-13-14-35, frame 000154

# %%
# Out:
# Camera image of the scene 2020-02-28-13-14-35, frame 000173

# %%
# Range-Doppler visualization
signal_visualizer = SignalVisualizer(rd_matrix)
print('Raw Range-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='range_doppler', color_scale=False,
                             rotation=True, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_doppler'][annotation_type]
        annot_generator = AnnotationGenerator(rd_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Doppler with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/rd_{}.png'.format(annotation_type),
                                                signal_type='range_doppler', color_scale=False,
                                                rotation=True, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# Raw Range-Doppler representation:
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_27967/1529025922.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/1529025922.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/1529025922.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/1529025922.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/1529025922.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/1529025922.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/1529025922.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/1529025922.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27967/1529025922.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27967/1529025922.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 8
#       6 for annotation_type in ['sparse', 'dense', 'box']:
#       7     for i, instance in enumerate(instances):
# ----> 8         points = annotations[instance]['range_doppler'][annotation_type]
#       9         annot_generator = AnnotationGenerator(rd_matrix.shape, points)
#      10         if annotation_type is 'sparse':
#
# KeyError: '000010'

# %%
# Range-Angle visualization

signal_visualizer = SignalVisualizer(ra_matrix)
print('Raw Range-Angle representation:')
signal_visualizer.save_scale(path='.', signal_type='range_angle', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
for annotation_type in ['sparse', 'dense', 'box']:
    for i, instance in enumerate(instances):
        points = annotations[instance]['range_angle'][annotation_type]
        annot_generator = AnnotationGenerator(ra_matrix.shape, points)
        if annotation_type is 'sparse':
            annots = annot_generator.get_points()
        elif annotation_type is 'dense':
            annots = annot_generator.get_mask()
        else:
            annots = annot_generator.get_box()
        signal_visualizer.add_annotation(i, annots, annotation_type)
    print('Range-Angle with {} annotations:'.format(annotation_type))
    signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                                signal_type='range_angle', color_scale=False,
                                                rotation=False, save_img=False, plot_img=True)
    signal_visualizer.reset_annotation()
# Out:
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Raw Range-Angle representation:
# /tmp/ipykernel_27616/3271338884.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27616/3271338884.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27616/3271338884.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27616/3271338884.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27616/3271338884.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27616/3271338884.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27616/3271338884.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27616/3271338884.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# /tmp/ipykernel_27616/3271338884.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if annotation_type is 'sparse':
# /tmp/ipykernel_27616/3271338884.py:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif annotation_type is 'dense':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 8
#       6 for annotation_type in ['sparse', 'dense', 'box']:
#       7     for i, instance in enumerate(instances):
# ----> 8         points = annotations[instance]['range_angle'][annotation_type]
#       9         annot_generator = AnnotationGenerator(ra_matrix.shape, points)
#      10         if annotation_type is 'sparse':
#
# KeyError: '000015'

# %%
# Range-Angle visualization

signal_visualizer = SignalVisualizer(ad_matrix)
print('Raw Angle-Doppler representation:')
signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
                             rotation=False, save_img=False, plot_img=True)
print('Range-Angle with {} annotations:'.format(annotation_type))
signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
                                            signal_type='range_angle', color_scale=False,
                                            rotation=False, save_img=False, plot_img=True)
signal_visualizer.reset_annotation()
# Out:
# Raw Angle-Doppler representation:
# Range-Angle with sparse annotations:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 7
#       4 signal_visualizer.save_scale(path='.', signal_type='angle_doppler', color_scale=False,
#       5                              rotation=False, save_img=False, plot_img=True)
#       6 print('Range-Angle with {} annotations:'.format(annotation_type))
# ----> 7 signal_visualizer.save_multiple_annotations(path='/root/workspace/temp/ra_{}.png'.format(annotation_type),
#       8                                             signal_type='range_angle', color_scale=False,
#       9                                             rotation=False, save_img=False, plot_img=True)
#      10 signal_visualizer.reset_annotation()
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:161, in SignalVisualizer.save_multiple_annotations(self, path, signal_type, color_scale, rotation, save_img, plot_img)
#     141 def save_multiple_annotations(self, path, signal_type='range_doppler', color_scale=None,
#     142                               rotation=False, save_img=True, plot_img=False):
#     143     """
#     144     Method to save the image with all the added annotations
#     145
#    (...)
#     159         Plot the image
#     160     """
# --> 161     transformed_image = self._get_multiple_annotated_image()
#     162     img = self._format_img(transformed_image, signal_type, color_scale, rotation)
#     163     if save_img:
#
# File ~/Repositories/carrada_dataset/carrada_dataset/utils/visualize_signal.py:255, in SignalVisualizer._get_multiple_annotated_image(self)
#     253 zeros = np.zeros(mask.shape).astype(np.uint8)
#     254 if len(self.masks) == 0:
# --> 255     raise Exception('You need to add annotation before visualize it!')
#     256 transformed_image = self.image.copy()
#     257 transformed_image = (transformed_image * 255).astype(np.uint8)
#
# Exception: You need to add annotation before visualize it!

# %%
matrix = ad_matrix
min_value, max_value = np.min(matrix), np.max(matrix)
cmap = plt.get_cmap('plasma')
norm = colors.Normalize(vmin=min_value, vmax=max_value)
colored_matrix = cmap(norm(matrix))
colored_matrix = colored_matrix[:, :, :3]
x_shape, y_shape, _ = colored_matrix.shape
color_scale_params = [cmap, norm]

# %%
plt.plot(colored_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.plot(colored_matrix)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib/axes/_base.py:507, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
# --> 507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#     509 if x.ndim == 1:
#     510     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (256,) and (256, 64, 3)

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
plt.show(ad_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 import matplotlib.colors as colors
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.show(ad_matrix)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib/pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/anaconda3/envs/carrada/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
